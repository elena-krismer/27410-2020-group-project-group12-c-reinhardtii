# %% [markdown]
# # Report

# %% [markdown]
# # 1. Introduction

# %%
from IPython.display import Image

# %% [markdown]
# ## 1.1. Literature review on the compound

# %% [markdown]
# One of the greatest challenges of this century is finding alternative, sustainable, enviromentally friendly energy sources. Looking at the possible current solutions, hydrogen is considered an optimal energy source due to its high output energy per unit of mass and its only combustion product H2O (Xu et al., 2019). Currently, the production of hydrogen is neither economically efficient nor sustainable, as a huge part of the produced hydrogen comes from fossil fuels. Further sources of hydrogen production are: steam-methane reforming (SMR), methanol steam forming, and electrolysis of water. Solar energy, solar photovolatic and photon-eletcrolysis are some examples of renewable methods with the ability to produce hydrogen. However, these methods have shown a lack in efficiency (Knzouz et al., 2020). Hydrogen production costs in 2014 of different technologies are presented in Figure 1 (Grab-Rogaliński & Szwaja, 2014), where we see that, eventhough the cheapest methods are coal gasification and SMR, they are energy intensive processes that require high temperatures and they aren't sustainable solutions. That is why our focus is put on hydrogen production from algae biomass (included in the 'Biological processes' bar of Fig. 1), since production costs are not as high as other sustainable processes like wind energy and electrolysis of H2O.

# %%
Image(filename = "figures/hydrogen_costs.png", width = 600, height = 300)

# %% [markdown]
# Figure 1. Hydrogen production costs from different technologies (Grab-Rogaliński & Szwaja, 2014).

# %% [markdown]
# Owing to the efficent solar energy conversion and easy cultivation, algae represents an assuring organism for hydrogen production (Xu et al., 2019). Algal biomass is considered an attractive raw material for hydrogen production, since the photobioreactors and open-air systems used allow for careful cultivation control, and cheaper and simpler cultivation methods, respectively (Sharma & Arya, 2017).
#
# Formation of hydrogen gas is catalyzed by the hydrogenase enzyme. In algae, we find different types of hydrogenases according to the composition of the bimetallic active site cofactor: [FeFe], [NiFe] and [Fe] hydrogenases. Whereas most [NiFe] hydrogenases carry out hydrogen uptake, [FeFe] hydrogenases mainly produce molecular hydrogen, and [Fe] hydrogenases catalyze a specific reaction utilizing H2 (Stripp & Happe, 2009).

# %%
Image(filename = "figures/types of hydrogenases.jpg", width = 600, height = 300)

# %% [markdown]
# Figure 2. Structure of the 3 hydrogenases present in algae (Shima et al., 2008).

# %% [markdown]
# In our cell factory organism, Chlamydomonas reinhardtii, hydrogen formation is catalzyed by [FeFe] hydrogenase, particularly by two chloroplast hydrogenases identified in previous studies (HydA1 and HydA2) (Reifschneider-Wegner et al., 2014). In our model, this enzyme is located in the cytoplasm, mitochondria and chloroplast, and it uses electrons from the photsynthetic light reactions to catalyze hydrogen evolution (Murthy & Ghirardi, 2013). Hydrogen production is light-dependent, since the [FeFe] hydrogenases are coupled to the photosynthetic electron transport chain via ferredoxin (Stripp & Happe, 2009). This enzyme is considered a strong candidate for an integral part of the solar H2 production system due to the fact that it offers an additional advantage of high turnover frequency, which means that this enzyme is generally more active than the others (Smith et al., 2012).

# %%
Image(filename = "figures/hydrogenase.jpg", width = 600, height = 300)

# %% [markdown]
# Figure 3. Scheme of Hydrogen Production in algae (Burgess et al., 2011).

# %% [markdown]
# ## 1.2 Literature review of the cell factory

# %% [markdown]
# Microalgae are a diverse group of phototrophic eukaryotic unicellular microorganisms, which have been widely studied for pure and applied research. Due to their natural synthesis of value-added natural products, they are emerging as a source of sustainable chemical compounds, proteins and metabolites (Scaife et al., 2015). In the recent years, microalgae-derived biofuels attracted significant attention, as they offer renewable and eco-friendly energy source, without compromising food supplies, forest or arable land.
#
# We chose the green microalgae Chlamydomonas reinhardtii, due to its sequenced genome, the ease of cultivation and low cost, and the high hydrogenase activity, which catalyzes the reaction of hydrogen formation (Xu et al., 2019). Another reason is the availability of high-quality and up-to-date genome-scale models (GSM). While accessing different microalgae, we realized that many GSM are still quite rudimentary, which is an important aspect since microalgae contain a big number of metabolic reactions spread across many compartments. C. reinhardtii has been studied extensively in the past decades and serves as a model organism for the study of many cellular processes (Imam et al., 2015).
#
# Other alternatives employed for hydrogen production are bacteria, since they present faster production, lower inputs and don’t require big ponds for cultivation. However, there's still many challenges to be addressed, like improvement of rates and yields of H2 production, reactor system optimization, identifying feedstock sources and processing methods with the highest yields, and minimizing the costs of the reactor components.
#
# Nowadays, hydrogen production is expensive, and the energy output hardly exceeds the input. After discovering the presence of hydrogen metabolism in the green algae Scenedesmus obliquus (Gaffron, 1939), hydrogen biosynthesis from algae became a subject of great interest amongst researchers. Many advantages exist when using algae for this purpose, such as higher growth rate with superior CO2 fixation capacity, no need for arable land to grow, accumulation of large quantities of carbohydrate biomass, and the fact that they do not contain lignin (Wang & Yin, 2018).
#
# However, the main disadvantage of this model organism is that its biomass growth is very slow, so testing and analyzing in the wet lab all the experimental results obtained in the dry lab will take longer time since we also have to assess the outcomes in the following offspring.
# Currently, production of bio-hydrogen is not practicable because of low biomass concentration and costly downstreaming processes (Sharma & Arya, 2017).

# %% [markdown]
# # 2. Problem definition

# %% [markdown]
# Nowadays, the development of clean energy sources is a crucial process needed to reduce the environmental pollution associated with fossil fuels. That is why more efforts have been evolved in renewable economic and sustainable clean energy sources, so governments are now proactive in addressing secured supply of raw materials. Many potential candidate fuels have been studied in the energy area, being hydrogen one of the most promsing candidates; and many different biomass sources are also being assessed in order to determine the most promising one when it comes to biofuel production.
#
# Since not very efficient and conclusive results have been obtained when it comes to the production of hydrogen through microorganisms, due to the low biomass concentration and costly downstreaming process (Sharma & Arya, 2017), our objective is to improve the production rates and yield of this process by modifying different parameters, pathways and reactions involved in hydrogen production within our C. reinhardtii GSM model. We will also look into the medium used to grow our organism in order to assess which compounds are the best sources of C, N, P and S, and how these improve the growth rate by employing these as the only source of each respective element.

# %% [markdown]
# # 3. Selection and assessment of exisiting GSM

# %% [markdown]
# The model we sed for this assignment is iCre1355 (Imam et al., 2015), which is the newest genome scale model available as a SBML file. It includes 1963 genes, 2394 reactions, 1845 metabolites and 11 cellular compartements. iCre1355 is an improvement of the previously published GSM for C. reinhardtii iRC1080 (Chang et al., 2011), which includes 1080 genes, 2190 reactions, 1068 metabolites and 10 cellular compartments. C. reinhardtii‐specific metabolic and genomic information from the databases Plant metabolic network (ChlamyCyc 4.0), KEGG (Kanehisa et al., 2002, 2014), NCBI and Phytozome 10.1 were integrated into this model, as well as data obtained from high‐throughput transcriptomics experiments.
#
# After completing the model, the authors actually conducted several experiments to contrast the accuracy of the new model's predictions. A collection of 306 different genotype-phenotype conditions, obtained from 81 different mutants, was listed, and iCre1335 was used to predict the phenotypes of these mutants. The model showed a sensitivity of 83% and a specificity of 92%, overall achieving an area under the Receiver Operating Curve (ROC) of 0.92. This means that only in 17% of the cases, the expression of a phenotype was predicted incorrectly; and in 8% of the cases, the lack of expression of a phenotype was predicted incorrectly.
#
# Authors further tested the model by comparing the predicted growth rates under different metabolic conditions, and the different C, N and P uptake rates with experimental cultures, obtaining a good agreement ($R^{2}$ = 0.82) between experimental and predicted values. Moreover, the model actually was able to predict growth halt and lipid accumulation due to nitrogen starvation, but unfortunately, it was unable to correctly predict the effect of light intensity changes in growth rate. In this case, the authors had to manually tune the photon uptake rate to match predictions with experimental results.
#
# Overall, the authors were fairly confident of the predictive capabilities of the model. In order to independently verify that statement, we conducted our own validation, by uploading the file to memote, to analyse the consistency of the model. The report obtained, which has been added to this project's repository, shows that the model was quite satisfactory. Almost the totality of the reactions are both mass and charge balanced, there are almost no disconnected metabolite (meaning that they are not used in any reaction) and most of the reactions are not able to carry unlimited amounts of flux. The main problems are the lack of stoichiometric consistency, meaning that it is not possible to assign to each metabolite a positive molecular mass without breaking mass conservation at some point in the model (this is probably caused by the few reactions that are not mass balanced); and the fact that all metabolites, reactions and genes do not have any reference (annotation) linking them to one major database.

# %% [markdown]
# # 4. Computer aided Cell Factory Engineering

# %% [markdown]
# ## 4.X. Identification of Potential Targets Genes

# %%
#add link

# %% [markdown]
# The code for this chapter can be found [here](./Appendices/4_x_Identifying_Genes_for_Overexpression(1).ipynb).

# %% [markdown]
# In the following part, we aimed to identify gene amplification targets, therefore we used Flux scanning based on enforced objective flux (FSEOF). This method allows to identify fluxes, which rise when the hydrogen production is enforced to be a specific value. The genes of those reactions are seen as potential target genes for overexpression. This approach is described by Choi et al. 2010.

# %% [markdown]
# Overall there were about 100 active fluxes under hydrogen production, the positive and negative fluxes under hydrogen production are depicted in Figure X. In Figure X. the fluxes with a change of more than 50% are presented. Additionally, there were oscillating fluxes. You can find the graph of highly oscillating fluxes in the [appendices - add link](xxx).

# %%
Image(filename = "figures/FSOEF_mixo.png")

# %% [markdown]
# x. Figure. Fluxes under enforced hydrogen production

# %%
Image(filename = "figures/ChangeInFlux_mixo.png")

# %% [markdown]
# X. Figure Significantelly changing fluxes under hydrogen production.

# %% [markdown]
# Finally, we selected those reactions with an increase in flux of more than 30% and created a dict with potential target genes.
# ​
# Our findings included also reactions, which are described by Xu et al. 2019 as potential targets for elevating hydrogen production amongst other things, [dark fermentation](https://en.wikipedia.org/wiki/Dark_fermentation). Hereby the results of the FSEOF suggest the [Pyruvate Synthase](https://www.brenda-enzymes.org/enzyme.php?ecno=1.2.7.1), active in dark fermentation, as a potential gene for amplification. The role of pyruvate synthase in C.reinhardtii for hydrogen production has been described by Noth et al. (2013).  In further steps, an exact evaluation of those pathways and finally experiments in the wet lab are required to estimate the impact of the overexpression of the selected genes. However, this would/should be part of another project.
# ​
# ​
# ### Identified Reactions:

# %% [markdown]
# (FeFe)-hydrogenase, chloroplast
#
# **Fermentation**:
# - [Phosphotransacetylase](https://www.brenda-enzymes.org/enzyme.php?ecno=2.3.1.8)
# - [Pyruvate synthase](https://www.brenda-enzymes.org/enzyme.php?ecno=1.2.7.1)
#
#
# **Citrat Cyklus**:[Aconitate hydratase](https://www.genome.jp/dbget-bin/www_bget?ko:K01681), [Isocitrate lyase](https://www.brenda-enzymes.org/enzyme.php?ecno=4.1.3.1), [Citrate synthase](https://www.brenda-enzymes.org/enzyme.php?ecno=2.3.3.1), [Fumarate hydratase](https://www.brenda-enzymes.org/enzyme.php?ecno=4.2.1.2), [malate dehydrogenase](https://www.brenda-enzymes.org/enzyme.php?ecno=1.1.1.299), [succinate dehydrogenase Complex II](https://www.brenda-enzymes.org/enzyme.php?ecno=1.3.5.1)
#
# **Oxidative Phosphorylation**: [F0F1-ATP synthase Complex V](https://www.genome.jp/dbget-bin/www_bget?cre:CHLREDRAFT_136578), [NADH:ubiquinone oxidoreductase Complex I](https://www.brenda-enzymes.org/enzyme.php?ecno=7.1.1.2), [ubiquinol-cytochrome c oxidoreductase Complex III](https://www.genome.jp/dbget-bin/www_bget?cre:CHLREDRAFT_206235), [Inorganic diphosphatase](https://www.brenda-enzymes.org/enzyme.php?ecno=3.6.1.1), [cytochrome c oxidase Complex IV](https://www.brenda-enzymes.org/enzyme.php?ecno=7.1.1.9)
#
# **Glycolisis**: [glyceraldehyde-3-phosphate dehydrogenase (phosphorylating)](https://www.brenda-enzymes.org/enzyme.php?ecno=1.2.1.12)
#
# **Carbon fixation**:[phosphoenolpyruvate carboxykinase](https://www.brenda-enzymes.org/enzyme.php?ecno=4.1.1.31), [pyruvate kinase](https://www.brenda-enzymes.org/enzyme.php?ecno=2.7.1.40)
#
# **Metabolism**:[Serine racemase](https://www.brenda-enzymes.org/enzyme.php?ecno=5.1.1.18), [Aspartate aminotransferase](https://www.brenda-enzymes.org/enzyme.php?ecno=2.6.1.1), [glutamate dehydrogenase](https://www.brenda-enzymes.org/enzyme.php?ecno=1.4.1.2), [glutamate synthase (NADH)](https://www.brenda-enzymes.org/enzyme.php?ecno=1.4.1.13), [glutamate---ammonia ligase, cytosol](https://www.genome.jp/dbget-bin/www_bget?cre:CHLREDRAFT_116196), [malate synthase](https://www.brenda-enzymes.org/enzyme.php?ecno=2.3.1.182), [phosphoglycerate kinase](https://www.brenda-enzymes.org/enzyme.php?ecno=1.1.1.95), [threonine ammonia-lyase (D-serine)](https://www.brenda-enzymes.org/enzyme.php?ecno=4.3.1.19)
#
# **Transporter**: [Amino acid transporter](https://www.genome.jp/dbget-bin/www_bget?cre:CHLREDRAFT_206100) (asp-L), mitochondrial, [Dicarboxylate/tricarboxylate carrier (mal:oaa), mitochondrial](https://www.genome.jp/dbget-bin/www_bget?crb:17881295), Glyceraldehyde 3-phosphate transport via triose-phosphate translocator (from chloroplast), H2O transport, extracellular, Vacuolar amino acid transporter (gln-L), chloroplast, phosphate transport, mitochondrial, spermidine:proton symporter (irreversible), mitochondria

# %% [markdown]
# # 5. Discussion

# %% [markdown]
# <500 words
# discuss your results. Is it likely that you will be successful? What are the underlying assumptions? How could risks be minimized? What are the next steps towards implementation?

# %% [markdown]
# ## 5.1. Other insights

# %% [markdown]
# Besides hydrogen production in algae, we also examined the production of lipids. Due to the high lipid content in some species, algae is a promising organism for biofuel production (Peng et al., 2019). Our approach was to optimize the lipid production in C. reinhardtii by making modifications to the medium and reactions in the pathways. However, the complexitiy of the lipid pathways and the wide range of fatty acids made it difficult to add changes and measure a final product. Nonetheless, examining the lipid pathway in a GSM should be considered in further studies.
#
# When investigating our GSM from C. reinhardtii, we found several exchange reactions in which pharmaceutical chemicals were involved. For instance, 6-Mercaptopurine and Tegafur, which are used in chemotherapy (Bertholee et al., 2017); Citalopram, which is used as an antidepressant (Bezchlibnyk-Butlerm et al., 2000); and Lidocain, a widely used local anesthetic (Golzari et al., 2014). Unfortunately, there are barely any papers which describe interactions of C. reinhardtii with these compounds. Considering that these drugs have tremendous effects on the cell, further research would be necessary in order to provide more insight into the drug metabolism of C. reinhardtii.

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# <200 words
# A summary of your strategy, expected outcome, and the impact of the project, should you achieve what you are trying to do.

# %% [markdown]
# # 7. Reference List

# %% [markdown]
# Burgess SJ, Tamburic B, Zemichael F, Hellgardt K, Nixon PJ. Solar-driven hydrogen production in green algae. Adv Appl Microbiol. 2011;75:71-110. doi: 10.1016/B978-0-12-387046-9.00004-9. PMID: 21807246. https://doi.org/10.1016/B978-0-12-387046-9.00004-9
#
# Bertholee D, Maring JG, van Kuilenburg AB. Genotypes Affecting the Pharmacokinetics of Anticancer Drugs. Clin Pharmacokinet. 2017;56(4):317-337. doi:10.1007/s40262-016-0450-z
#
# Bezchlibnyk-Butler K, Aleksic I, Kennedy SH. Citalopram--a review of pharmacological and clinical effects. J Psychiatry Neurosci. 2000;25(3):241-254.
#
# Chang, Roger L, Ghamsari, Lila, Manichaikul, Ani, Hom, Erik F Y, Balaji, Santhanam, Fu, Weiqi, Shen, Yun, Hao, Tong, Palsson, Bernhard Ø, Salehi‐Ashtiani, Kourosh, Papin, Jason A, (2011) Metabolic network reconstruction of Chlamydomonas offers insight into light‐driven algal metabolism. Molecular Systems Biology, 7. 518. https://doi:accession:10.1038/msb.2011.52
#
# Gaffron, H. (1939). Reduction of carbon dioxide with molecular hydrogen in green algae. Nature, 143(3614), 204-205.
#
# Golzari SE, Soleimanpour H, Mahmoodpoor A, Safari S, Ala A. Lidocaine and pain management in the emergency department: a review article. Anesth Pain Med. 2014;4(1):e15444. Published 2014 Feb 15. doi:10.5812/aapm.15444
#
# Grab-Rogaliński, K., & Szwaja, S. (2014). Cost analysis of hydrogen energy generation. Journal of KONES, 21. DOI:10.5604/12314005.1133183
#
# Imam S, Schäuble S, Valenzuela J, López García de Lomana A, Carter W, Price ND, Baliga NS. A refined genome-scale reconstruction of Chlamydomonas metabolism provides a platform for systems-level analyses. Plant J. 2015 Dec;84(6):1239-56. doi: 10.1111/tpj.13059. Epub 2015 Nov 30. PMID: 26485611; PMCID: PMC4715634. https://github.com/baliga-lab/Chlamy_model_iCre1355
#
# Imam, S., Schäuble, S., Valenzuela, J., López García de Lomana, A., Carter, W., Price, N. D., & Baliga, N. S. (2015). A refined genome‐scale reconstruction of Chlamydomonas metabolism provides a platform for systems‐level analyses. The Plant Journal, 84(6), 1239-1256. DOI: https://doi.org/10.1111/tpj.13059
#
# Kanehisa, M., Goto, S., Kawashima, S., & Nakaya, A. (2002). The KEGG databases at GenomeNet. Nucleic acids research, 30(1), 42-46. DOI: https://doi.org/10.1093/nar/30.1.42
#
# Kanehisa, M., Goto, S., Sato, Y., Kawashima, M., Furumichi, M., & Tanabe, M. (2014). Data, information, knowledge and principle: back to metabolism in KEGG. Nucleic acids research, 42(D1), D199-D205. DOI: https://doi.org/10.1093/nar/gkt1076
#
# Khzouz, M., & Gkanas, E. I. (2020). Hydrogen Technologies for Mobility and Stationary Applications: Hydrogen Production, Storage and Infrastructure Development. In Renewable Energy-Resources, Challenges and Applications. IntechOpen. DOI: http://dx.doi.org/10.5772/intechopen.91676
#
# Salguero, D. A. M., Fernández-Niño, M., Serrano-Bermúdez, L. M., Melo, D. O. P., Winck, F. V., Caldana, C., & Barrios, A. F. G. (2018). Development of a Chlamydomonas reinhardtii metabolic network dynamic model to describe distinct phenotypes occurring at different CO2 levels. PeerJ, 6, e5528. doi:10.7717/peerj.5528 https://www.embopress.org/action/downloadSupplement?doi=10.1038%2Fmsb.2011.52&file=msb201152-sup-0015.zip
#
# Murthy, U. M. N., & Ghirardi, M. L. (2013). Algal Hydrogen Production. Encyclopedia of Biological Chemistry (Second Edition). Academic Press. Pages 66-70.
#
# Peng, L., Fu, D., Chu, H. et al. Biofuel production from microalgae: a review. Environ Chem Lett 18, 285–297 (2019). https://doi.org/10.1007/s10311-019-00939-0
#
# Reifschneider-Wegner, K., Kanygin, A., & Redding, K. E. (2014). Expression of the [FeFe] hydrogenase in the chloroplast of Chlamydomonas reinhardtii. International journal of hydrogen energy, 39(8), 3657-3665. https://doi.org/10.1016/j.ijhydene.2013.12.157
#
# Scaife, M. A., Nguyen, G. T., Rico, J., Lambert, D., Helliwell, K. E., & Smith, A. G. (2015). Establishing Chlamydomonas reinhardtii as an industrial biotechnology host. The Plant Journal, 82(3), 532-546. DOI: https://doi.org/10.1111/tpj.12781
#
# Sharma, A., & Arya, S. K. (2017). Hydrogen from algal biomass: a review of production process. Biotechnology reports, 15, 63-69. https://doi.org/10.1016/j.btre.2017.06.001
#
# Shima, S., Pilak, O., Vogt, S., Schick, M., Stagni, M. S., Meyer-Klaucke, W., Warkentin, E., Thauer, R. K. & Ermler, U. (2008). The crystal structure of [Fe]-hydrogenase reveals the geometry of the active site. Science, 321(5888), 572-575. https://doi.org/10.1126/science.1158978
#
# Smith, P. R., Bingham, A. S., & Swartz, J. R. (2012). Generation of hydrogen from NADPH using an [FeFe] hydrogenase. International journal of hydrogen energy, 37(3), 2977-2983. DOI: https://doi.org/10.1016/j.ijhydene.2011.03.172
#
# Stripp, S. T., & Happe, T. (2009). How algae produce hydrogen—news from the photosynthetic hydrogenase. Dalton transactions, (45), 9960-9969. DOI: https://doi.org/10.1039/B916246A
#
# Wang, J., & Yin, Y. (2018). Fermentative hydrogen production using pretreated microalgal biomass as feedstock. Microbial cell factories, 17(1), 22. DOI: https://doi.org/10.1186/s12934-018-0871-5
#
# Xu, L., Fan, J., & Wang, Q. (2019). Omics application of bio-hydrogen production through green alga Chlamydomonas reinhardtii. Frontiers in Bioengineering and Biotechnology, 7, 201. DOI: https://doi.org/10.3389/fbioe.2019.00201

# %% [markdown]
# # 8. List of Figures

# %% [markdown]
# Figure 1: Hydrogen production costs
#
# Figure 2: Structure of the 3 hydrogenases present in algae
#
# Figure 3: Scheme of Hydrogen Production in Algae
